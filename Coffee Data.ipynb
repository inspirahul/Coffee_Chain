# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
coffee = pd.read_csv(r'C:\Users\rahul\Desktop\Coffee Chain.csv', index_col='Ddate')

# %%
coffee.head()
# Out:
#         Area Code   Market   Market Size            Product Product Type  \
# Ddate
# 1/1/12        970  Central  Major Market  Decaf Irish Cream       Coffee
# 2/1/12        719  Central  Major Market  Decaf Irish Cream       Coffee
# 3/1/12        720  Central  Major Market  Decaf Irish Cream       Coffee
# 4/1/12        303  Central  Major Market  Decaf Irish Cream       Coffee
# 5/1/12        720  Central  Major Market  Decaf Irish Cream       Coffee
#
#            State   Type  Budget Cogs  Budget Margin  Budget Profit  \
# Ddate
# 1/1/12  Colorado  Decaf          100            140            110
# 2/1/12  Colorado  Decaf          100            140            110
# 3/1/12  Colorado  Decaf          100            140            110
# 4/1/12  Colorado  Decaf          100            150            120
# 5/1/12  Colorado  Decaf          110            150            120
#
#        Budget Sales  Coffee Sales  Cogs Inventory  Margin  Marketing  \
# Ddate
# ...

# %%
coffee['Product'].value_counts()
# Out:
# Colombian            480
# Caffe Mocha          480
# Lemon                480
# Decaf Espresso       408
# Darjeeling           384
# Decaf Irish Cream    384
# Chamomile            384
# Green Tea            288
# Earl Grey            288
# Caffe Latte          216
# Amaretto             192
# Mint                 192
# Regular Espresso      72
# Name: Product, dtype: int64

# %%
coffee = pd.read_csv(r'C:\Users\rahul\Desktop\Coffee Chain.csv', parse_dates=True, index_col='Ddate')

# %%
coffee.head()
# Out:
#             Area Code   Market   Market Size            Product Product Type  \
# Ddate
# 2012-01-01        970  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-02-01        719  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-03-01        720  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-04-01        303  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-05-01        720  Central  Major Market  Decaf Irish Cream       Coffee
#
#                State   Type  Budget Cogs  Budget Margin  Budget Profit  \
# Ddate
# 2012-01-01  Colorado  Decaf          100            140            110
# 2012-02-01  Colorado  Decaf          100            140            110
# 2012-03-01  Colorado  Decaf          100            140            110
# 2012-04-01  Colorado  Decaf          100            150            120
# 2012-05-01  Colorado  Decaf          110            150            120
#
# ...

# %%
coffee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4248 entries, 2012-01-01 to 2013-12-01
# Data columns (total 20 columns):
# Area Code            4248 non-null int64
# Market               4248 non-null object
# Market Size          4248 non-null object
# Product              4248 non-null object
# Product Type         4248 non-null object
# State                4248 non-null object
# Type                 4248 non-null object
# Budget Cogs          4248 non-null int64
# Budget Margin        4248 non-null int64
# Budget Profit        4248 non-null int64
# Budget Sales         4248 non-null object
# Coffee Sales         4248 non-null int64
# Cogs                 4248 non-null int64
# Inventory            4248 non-null object
# Margin               4248 non-null int64
# Marketing            4248 non-null int64
# Number of Records    4248 non-null int64
# Number Of Records    4248 non-null int64
# Profit               4248 non-null int64
# Total Expenses       4248 non-null int64
# ...

# %%
coffee.head()
# Out:
#             Area Code   Market   Market Size            Product Product Type  \
# Ddate
# 2012-01-01        970  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-02-01        719  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-03-01        720  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-04-01        303  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-05-01        720  Central  Major Market  Decaf Irish Cream       Coffee
#
#                State   Type  Budget Cogs  Budget Margin  Budget Profit  \
# Ddate
# 2012-01-01  Colorado  Decaf          100            140            110
# 2012-02-01  Colorado  Decaf          100            140            110
# 2012-03-01  Colorado  Decaf          100            140            110
# 2012-04-01  Colorado  Decaf          100            150            120
# 2012-05-01  Colorado  Decaf          110            150            120
#
# ...

# %%
#Total Profit on 2012-01-01
profit_2012_01_01 = coffee.loc['2012-01-01', 'Profit']
profit_2012_01_01.sum()
# Out:
# 8041

# %%
new = pd.DataFrame(coffee.loc['2012-01-01'])
new2 = pd.DataFrame(coffee.loc['2012-02-01'])

# %%
#Maximum orders form Central nd West market and Minimum orders from South market on 2012-01-01


new2['Market'].value_counts()
# Out:
# Central    56
# West       56
# East       37
# South      28
# Name: Market, dtype: int64

# %%
#Total Profit in Jan 2012

#Note: Profit in Jan 2012 and 2012-01-01 is same because all orders are on 1st date of every month.

profit_Jan_2012 = coffee.loc['2012-01','Profit']

# %%
profit_Jan_2012.sum()
# Out:
# 8041

# %%
coffee.loc['2012-02-01']
# Out:
#             Area Code   Market   Market Size            Product Product Type  \
# Ddate
# 2012-02-01        719  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-02-01        847  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-02-01        614  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-02-01        303  Central  Major Market     Decaf Espresso     Espresso
# 2012-02-01        312  Central  Major Market     Decaf Espresso     Espresso
# 2012-02-01        614  Central  Major Market     Decaf Espresso     Espresso
# 2012-02-01        970  Central  Major Market          Chamomile   Herbal Tea
# 2012-02-01        815  Central  Major Market          Chamomile   Herbal Tea
# 2012-02-01        330  Central  Major Market          Chamomile   Herbal Tea
# 2012-02-01        970  Central  Major Market              Lemon   Herbal Tea
# 2012-02-01        773  Central  Major Market              Lemon   Herbal Tea
# ...

# %%
coffee['Cogs'].resample('M').mean()
# Out:
# Ddate
# 2012-01-31    80.000000
# 2012-02-29    80.830508
# 2012-03-31    81.412429
# 2012-04-30    82.909605
# 2012-05-31    85.062147
# 2012-06-30    88.310734
# 2012-07-31    91.084746
# 2012-08-31    91.932203
# 2012-09-30    84.457627
# 2012-10-31    82.723164
# 2012-11-30    80.254237
# 2012-12-31    84.220339
# 2013-01-31    80.000000
# 2013-02-28    80.830508
# 2013-03-31    81.412429
# 2013-04-30    82.909605
# 2013-05-31    85.062147
# 2013-06-30    88.310734
# 2013-07-31    91.084746
# 2013-08-31    91.932203
# 2013-09-30    84.457627
# 2013-10-31    82.723164
# 2013-11-30    80.254237
# 2013-12-31    84.220339
# Freq: M, Name: Cogs, dtype: float64

# %%
coffee['Profit'].resample('M').mean()
# Out:
# Ddate
# 2012-01-31    45.429379
# 2012-02-29    47.282486
# 2012-03-31    47.259887
# 2012-04-30    48.983051
# 2012-05-31    50.548023
# 2012-06-30    54.073446
# 2012-07-31    55.960452
# 2012-08-31    54.045198
# 2012-09-30    48.067797
# 2012-10-31    49.005650
# 2012-11-30    47.451977
# 2012-12-31    49.779661
# 2013-01-31    70.757062
# 2013-02-28    70.163842
# 2013-03-31    70.141243
# 2013-04-30    72.672316
# 2013-05-31    69.762712
# 2013-06-30    74.677966
# 2013-07-31    77.237288
# 2013-08-31    74.604520
# 2013-09-30    71.338983
# 2013-10-31    72.757062
# 2013-11-30    70.395480
# 2013-12-31    73.949153
# Freq: M, Name: Profit, dtype: float64

# %%
coffee['Profit'].resample('M').sum()
# Out:
# Ddate
# 2012-01-31     8041
# 2012-02-29     8369
# 2012-03-31     8365
# 2012-04-30     8670
# 2012-05-31     8947
# 2012-06-30     9571
# 2012-07-31     9905
# 2012-08-31     9566
# 2012-09-30     8508
# 2012-10-31     8674
# 2012-11-30     8399
# 2012-12-31     8811
# 2013-01-31    12524
# 2013-02-28    12419
# 2013-03-31    12415
# 2013-04-30    12863
# 2013-05-31    12348
# 2013-06-30    13218
# 2013-07-31    13671
# 2013-08-31    13205
# 2013-09-30    12627
# 2013-10-31    12878
# 2013-11-30    12460
# 2013-12-31    13089
# Freq: M, Name: Profit, dtype: int64

# %%
coffee['Total Expenses'].resample('M').mean()
# Out:
# Ddate
# 2012-01-31    52.847458
# 2012-02-29    53.197740
# 2012-03-31    53.502825
# 2012-04-30    54.225989
# 2012-05-31    54.740113
# 2012-06-30    56.062147
# 2012-07-31    57.254237
# 2012-08-31    57.576271
# 2012-09-30    54.435028
# 2012-10-31    53.858757
# 2012-11-30    53.101695
# 2012-12-31    54.548023
# 2013-01-31    55.429379
# 2013-02-28    53.197740
# 2013-03-31    53.502825
# 2013-04-30    54.225989
# 2013-05-31    50.870056
# 2013-06-30    52.141243
# 2013-07-31    53.248588
# 2013-08-31    53.615819
# 2013-09-30    54.435028
# 2013-10-31    53.858757
# 2013-11-30    53.101695
# 2013-12-31    54.548023
# Freq: M, Name: Total Expenses, dtype: float64

# %%
coffee['Total Expenses'].resample('M').sum()
# Out:
# Ddate
# 2012-01-31     9354
# 2012-02-29     9416
# 2012-03-31     9470
# 2012-04-30     9598
# 2012-05-31     9689
# 2012-06-30     9923
# 2012-07-31    10134
# 2012-08-31    10191
# 2012-09-30     9635
# 2012-10-31     9533
# 2012-11-30     9399
# 2012-12-31     9655
# 2013-01-31     9811
# 2013-02-28     9416
# 2013-03-31     9470
# 2013-04-30     9598
# 2013-05-31     9004
# 2013-06-30     9229
# 2013-07-31     9425
# 2013-08-31     9490
# 2013-09-30     9635
# 2013-10-31     9533
# 2013-11-30     9399
# 2013-12-31     9655
# Freq: M, Name: Total Expenses, dtype: int64

# %%
coffee['Profit'].resample('M').sum().max()
# Out:
# 13671

# %%
coffee['Total Expenses'].resample('M').sum().max()
# Out:
# 10191

# %%
coffee['Product'].resample('M').count()
# Out:
# Ddate
# 2012-01-31    177
# 2012-02-29    177
# 2012-03-31    177
# 2012-04-30    177
# 2012-05-31    177
# 2012-06-30    177
# 2012-07-31    177
# 2012-08-31    177
# 2012-09-30    177
# 2012-10-31    177
# 2012-11-30    177
# 2012-12-31    177
# 2013-01-31    177
# 2013-02-28    177
# 2013-03-31    177
# 2013-04-30    177
# 2013-05-31    177
# 2013-06-30    177
# 2013-07-31    177
# 2013-08-31    177
# 2013-09-30    177
# 2013-10-31    177
# 2013-11-30    177
# 2013-12-31    177
# Freq: M, Name: Product, dtype: int64

# %%
two_months = coffee.loc['2012-01-01': '2012-02-01', 'Profit']

# %%
two_months
# Out:
# Ddate
# 2012-01-01    101
# 2012-02-01     99
# 2012-01-01     87
# 2012-02-01     95
# 2012-01-01      0
# 2012-02-01     -3
# 2012-01-01     53
# 2012-02-01     59
# 2012-01-01    140
# 2012-02-01    142
# 2012-01-01     16
# 2012-02-01     18
# 2012-01-01     99
# 2012-02-01     99
# 2012-01-01     95
# 2012-02-01    105
# 2012-01-01     29
# 2012-02-01     17
# 2012-01-01      0
# 2012-02-01     -3
# 2012-01-01     68
# 2012-02-01     68
# 2012-01-01     29
# 2012-02-01     28
# 2012-01-01     33
# 2012-02-01     33
# 2012-01-01    101
# 2012-02-01     99
# 2012-01-01     67
# 2012-02-01     71
#              ...
# 2012-01-01     33
# 2012-02-01     33
# 2012-01-01     34
# 2012-02-01     35
# 2012-01-01     13
# 2012-02-01     12
# 2012-01-01    203
# 2012-02-01    202
# 2012-01-01     28
# 2012-02-01     17
# 2012-01-01    -10
# 2012-02-01     -7
# 2012-01-01     70
# 2012-02-01     66
# 2012-01-01    141
# 2012-02-01    142
# 2012-01-01     68
# 2012-02-01     62
# ...

# %%
two_months.sum()
# Out:
# 16410

# %%
coffee.head()
# Out:
#             Area Code   Market   Market Size            Product Product Type  \
# Ddate
# 2012-01-01        970  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-02-01        719  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-03-01        720  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-04-01        303  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-05-01        720  Central  Major Market  Decaf Irish Cream       Coffee
#
#                State   Type  Budget Cogs  Budget Margin  Budget Profit  \
# Ddate
# 2012-01-01  Colorado  Decaf          100            140            110
# 2012-02-01  Colorado  Decaf          100            140            110
# 2012-03-01  Colorado  Decaf          100            140            110
# 2012-04-01  Colorado  Decaf          100            150            120
# 2012-05-01  Colorado  Decaf          110            150            120
#
# ...

# %%
coffee['Product'].str.upper()
# Out:
# Ddate
# 2012-01-01    DECAF IRISH CREAM
# 2012-02-01    DECAF IRISH CREAM
# 2012-03-01    DECAF IRISH CREAM
# 2012-04-01    DECAF IRISH CREAM
# 2012-05-01    DECAF IRISH CREAM
# 2012-06-01    DECAF IRISH CREAM
# 2012-07-01    DECAF IRISH CREAM
# 2012-08-01    DECAF IRISH CREAM
# 2012-09-01    DECAF IRISH CREAM
# 2012-10-01    DECAF IRISH CREAM
# 2012-11-01    DECAF IRISH CREAM
# 2012-12-01    DECAF IRISH CREAM
# 2013-01-01    DECAF IRISH CREAM
# 2013-02-01    DECAF IRISH CREAM
# 2013-03-01    DECAF IRISH CREAM
# 2013-04-01    DECAF IRISH CREAM
# 2013-05-01    DECAF IRISH CREAM
# 2013-06-01    DECAF IRISH CREAM
# 2013-07-01    DECAF IRISH CREAM
# 2013-08-01    DECAF IRISH CREAM
# 2013-09-01    DECAF IRISH CREAM
# 2013-10-01    DECAF IRISH CREAM
# 2013-11-01    DECAF IRISH CREAM
# 2013-12-01    DECAF IRISH CREAM
# 2012-01-01    DECAF IRISH CREAM
# 2012-02-01    DECAF IRISH CREAM
# 2012-03-01    DECAF IRISH CREAM
# 2012-04-01    DECAF IRISH CREAM
# 2012-05-01    DECAF IRISH CREAM
# ...

# %%
coffee['Product'].str.contains('GREEN')
# Out:
# Ddate
# 2012-01-01    False
# 2012-02-01    False
# 2012-03-01    False
# 2012-04-01    False
# 2012-05-01    False
# 2012-06-01    False
# 2012-07-01    False
# 2012-08-01    False
# 2012-09-01    False
# 2012-10-01    False
# 2012-11-01    False
# 2012-12-01    False
# 2013-01-01    False
# 2013-02-01    False
# 2013-03-01    False
# 2013-04-01    False
# 2013-05-01    False
# 2013-06-01    False
# 2013-07-01    False
# 2013-08-01    False
# 2013-09-01    False
# 2013-10-01    False
# 2013-11-01    False
# 2013-12-01    False
# 2012-01-01    False
# 2012-02-01    False
# 2012-03-01    False
# 2012-04-01    False
# 2012-05-01    False
# 2012-06-01    False
#               ...
# 2013-07-01    False
# 2013-08-01    False
# 2013-09-01    False
# 2013-10-01    False
# 2013-11-01    False
# 2013-12-01    False
# 2012-01-01    False
# 2012-02-01    False
# 2012-03-01    False
# 2012-04-01    False
# 2012-05-01    False
# 2012-06-01    False
# 2012-07-01    False
# 2012-08-01    False
# ...

# %%
coffee['Product'].str.contains('GREEN').sum()
# Out:
# 0

# %%
coffee = pd.read_csv(r'C:\Users\rahul\Desktop\Coffee Chain.csv', parse_dates=['Ddate'])

# %%
coffee['Product'].dtypes
# Out:
# dtype('O')

# %%
coffee = pd.read_csv(r'C:\Users\rahul\Desktop\Coffee Chain.csv', parse_dates=True, index_col='Ddate')

# %%
coffee['Product']
# Out:
# Ddate
# 2012-01-01    Decaf Irish Cream
# 2012-02-01    Decaf Irish Cream
# 2012-03-01    Decaf Irish Cream
# 2012-04-01    Decaf Irish Cream
# 2012-05-01    Decaf Irish Cream
# 2012-06-01    Decaf Irish Cream
# 2012-07-01    Decaf Irish Cream
# 2012-08-01    Decaf Irish Cream
# 2012-09-01    Decaf Irish Cream
# 2012-10-01    Decaf Irish Cream
# 2012-11-01    Decaf Irish Cream
# 2012-12-01    Decaf Irish Cream
# 2013-01-01    Decaf Irish Cream
# 2013-02-01    Decaf Irish Cream
# 2013-03-01    Decaf Irish Cream
# 2013-04-01    Decaf Irish Cream
# 2013-05-01    Decaf Irish Cream
# 2013-06-01    Decaf Irish Cream
# 2013-07-01    Decaf Irish Cream
# 2013-08-01    Decaf Irish Cream
# 2013-09-01    Decaf Irish Cream
# 2013-10-01    Decaf Irish Cream
# 2013-11-01    Decaf Irish Cream
# 2013-12-01    Decaf Irish Cream
# 2012-01-01    Decaf Irish Cream
# 2012-02-01    Decaf Irish Cream
# 2012-03-01    Decaf Irish Cream
# 2012-04-01    Decaf Irish Cream
# 2012-05-01    Decaf Irish Cream
# ...

# %%
coffee['Product'].resample('A').first()
# Out:
# Ddate
# 2012-12-31    Decaf Irish Cream
# 2013-12-31    Decaf Irish Cream
# Freq: A-DEC, Name: Product, dtype: object

# %%
coffee.head()
# Out:
#             Area Code   Market   Market Size            Product Product Type  \
# Ddate
# 2012-01-01        970  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-02-01        719  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-03-01        720  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-04-01        303  Central  Major Market  Decaf Irish Cream       Coffee
# 2012-05-01        720  Central  Major Market  Decaf Irish Cream       Coffee
#
#                State   Type  Budget Cogs  Budget Margin  Budget Profit  \
# Ddate
# 2012-01-01  Colorado  Decaf          100            140            110
# 2012-02-01  Colorado  Decaf          100            140            110
# 2012-03-01  Colorado  Decaf          100            140            110
# 2012-04-01  Colorado  Decaf          100            150            120
# 2012-05-01  Colorado  Decaf          110            150            120
#
# ...

# %%
type(coffee)
# Out:
# pandas.core.frame.DataFrame

# %%
type(coffee.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
profit = coffee['Profit']

# %%
total_expense = coffee['Total Expenses']

# %%
import seaborn as sns

# %%
plt.style.use('ggplot')

# %%
coffee['Profit'].hist()

# %%
plt.style.use('bmh')

# %%
coffee['Profit'].hist()

# %%
plt.style.use('fivethirtyeight')

# %%
coffee['Profit'].hist()

# %%
coffee['Profit'].hist(bins=30)

# %%
sns.barplot(x='Product', y='Profit', data=coffee)

# %%
sns.barplot(x='Product', y='Profit', data=coffee, estimator=np.std)

# %%
plt.figure(figsize=(18,4))

# %%
plt.figure(figsize=(26,4))
sns.barplot(x='Product', y='Profit', data=coffee)

# %%
plt.figure(figsize=(26,4))
sns.barplot(x='Product', y='Total Expenses', data=coffee)

# %%
plt.figure(figsize=(26,4))
sns.countplot(x='Product',data=coffee)

# %%
plt.figure(figsize=(26,4))
sns.countplot(x='Market',data=coffee)

# %%
plt.figure(figsize=(26,4))
sns.barplot(x='Market', y='Profit', data=coffee)

# %%
plt.figure(figsize=(26,4))
sns.barplot(x='Market', y='Total Expenses', data=coffee)
